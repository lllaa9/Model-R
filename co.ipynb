# %%
import numpy as np
import pandas as pd 
import matplotlib as mpl
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman')

# %%
from sklearn import ensemble
import seaborn as sns

# %%
data = pd.read_csv('co.csv')
number_col = [ col for col in data.columns if data[col].dtype != 'object']

category_col = [ col for col in data.columns if data[col].dtype == 'object']

# %%
LE = LabelEncoder()

for col in category_col:
    data[col] = LE.fit_transform(data[col])

# %%
#df = data.iloc[:, :9]

# %%
import seaborn as sns

# %%
#sns.pairplot(df)

# %%
#sns.set_theme(style="whitegrid",font='Times New Roman')
plt.figure(figsize=(800,800))
sns.set(font='Times New Roman', font_scale=1.6)
#sns.set_context({'figure.figsize':[40, 40]})

ax=sns.pairplot(df ,hue ='Degradation rate',x_vars=['Calcination temperature' ,'Dopant','Dopant/Ti mole ratio' ,'Catalyst/Pollutant mass ratio'], y_vars=['Calcination temperature' ,'Dopant','Dopant/Ti mole ratio' ,'Catalyst/Pollutant mass ratio'],kind= 'reg',palette='muted')
#ax._legend.remove()
plt.tight_layout()
ax._legend.set_bbox_to_anchor((1.15, 0.5))
#plt.legend(['20', '40', '60', '80', '100'], bbox_to_anchor=(0.9, 0.6))
plt.savefig('E:/111/co600.jpg',bbox_inches = 'tight', dpi=600)
#sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale=1.1)

sns.pairplot(df ,hue ='Degradation rate',x_vars=['Catalyst/Pollutant mass ratio','pH' ,'Light wavelength' ,'Illumination time'], y_vars=['Catalyst/Pollutant mass ratio','pH','Light wavelength' ,'Illumination time'],kind= 'reg',palette='muted')

# %%
sns.set(font_scale=1.3)

sns.pairplot(df ,hue ='Degradation rate',x_vars=['Dopant','Dopant/Ti mole ratio' ,'Calcination temperature' ,'Pollutant' ,'Catalyst/Pollutant mass ratio', 'pH' ,'Experimental temperature','Light wavelength' ,'Illumination time',], y_vars=['Dopant','Dopant/Ti mole ratio' ,'Calcination temperature' ,'Pollutant' ,'Catalyst/Pollutant mass ratio' ,'pH','Experimental temperature', 'Light wavelength' ,'Illumination time'],kind= 'reg',palette='muted')

# %%
plt.figure(figsize=(10,10))
sns.set(font='Times New Roman', font_scale=1.8)
sns.heatmap(df.corr(),annot=True, cmap="YlGnBu",annot_kws={"size":16})
plt.savefig('E:/111/H600.jpg',bbox_inches = 'tight', dpi=600)
